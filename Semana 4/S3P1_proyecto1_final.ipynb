# %% [markdown]
# ![image info](https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/images/banner_1.png)

# %% [markdown]
# # Proyecto 1 - Predicción de precios de vehículos usados
#
# En este proyecto podrán poner en práctica sus conocimientos sobre modelos predictivos basados en árboles y ensambles, y sobre la disponibilización de modelos. Para su desasrrollo tengan en cuenta las instrucciones dadas en la "Guía del proyecto 1: Predicción de precios de vehículos usados".
#
# **Entrega**: La entrega del proyecto deberán realizarla durante la semana 4. Sin embargo, es importante que avancen en la semana 3 en el modelado del problema y en parte del informe, tal y como se les indicó en la guía.
#
# Para hacer la entrega, deberán adjuntar el informe autocontenido en PDF a la actividad de entrega del proyecto que encontrarán en la semana 4, y subir el archivo de predicciones a la [competencia de Kaggle](https://www.kaggle.com/t/b8be43cf89c540bfaf3831f2c8506614).

# %% [markdown]
# ## Datos para la predicción de precios de vehículos usados
#
# En este proyecto se usará el conjunto de datos de Car Listings de Kaggle, donde cada observación representa el precio de un automóvil teniendo en cuenta distintas variables como: año, marca, modelo, entre otras. El objetivo es predecir el precio del automóvil. Para más detalles puede visitar el siguiente enlace: [datos](https://www.kaggle.com/jpayne/852k-used-car-listings).

# %% [markdown]
# ## Ejemplo predicción conjunto de test para envío a Kaggle
#
# En esta sección encontrarán el formato en el que deben guardar los resultados de la predicción para que puedan subirlos a la competencia en Kaggle.

# %%
pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask) (1.7.0)
# Requirement already satisfied: colorama in c:\users\karen\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask-restx
# Out:
# Requirement already satisfied: flask-restx in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (1.3.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: aniso8601>=0.82 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask-restx) (9.0.1)
# Requirement already satisfied: jsonschema in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask-restx) (4.21.1)
# Requirement already satisfied: Flask!=2.0.0,>=0.8 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask-restx) (3.0.3)
# Requirement already satisfied: werkzeug!=2.0.0 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask-restx) (3.0.2)
# Requirement already satisfied: pytz in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask-restx) (2024.1)
# Requirement already satisfied: importlib-resources in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from flask-restx) (6.4.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (1.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from werkzeug!=2.0.0->flask-restx) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->flask-restx) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->flask-restx) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->flask-restx) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\karen\appdata\local\programs\python\python312\lib\site-packages (from jsonschema->flask-restx) (0.18.0)
# Requirement already satisfied: colorama in c:\users\karen\appdata\roaming\python\python312\site-packages (from click>=8.1.3->Flask!=2.0.0,>=0.8->flask-restx) (0.4.6)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import pandas as pd
import numpy as np

# %%
# Carga de datos de archivo .csv
dataTraining = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/dataTrain_carListings.zip')
dataTesting = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/dataTest_carListings.zip', index_col=0)

# %%
# Visualización datos de entrenamiento
dataTraining.head()
# Out:
#    Price  Year  Mileage State       Make      Model
# 0  34995  2017     9913    FL       Jeep   Wrangler
# 1  37895  2015    20578    OH  Chevrolet   Tahoe4WD
# 2  18430  2012    83716    TX        BMW      X5AWD
# 3  24681  2014    28729    OH   Cadillac  SRXLuxury
# 4  26998  2013    64032    CO       Jeep   Wrangler

# %%
# Visualización datos de test
dataTesting.head()
# Out:
#     Year  Mileage State    Make        Model
# ID
# 0   2014    31909    MD  Nissan    MuranoAWD
# 1   2017     5362    FL    Jeep     Wrangler
# 2   2014    50300    OH    Ford  FlexLimited
# 3   2004   132160    WA     BMW            5
# 4   2015    25226    MA    Jeep        Grand

# %% [markdown]
# ## Preprocesamiento de datos (10 puntos)
#
# Los datos de entrenamiento se dividen en datos de entrenamiento y validación. Si decidieron preprocesar los datos (estandarizar, normalizar, imputar valores, etc), estos son correctamente preprocesados al ajustar sobre los datos de entrenamiento (.fit_transform()) y al transformar los datos del set de validación (.transform()). (10 puntos)

# %%
# Preprocesamiento de datos
dataTraining = dataTraining.drop(['Make', 'State'], axis=1)
dataTraining = dataTraining.join(pd.get_dummies(dataTraining['Model'], prefix='M'))
dataTraining = dataTraining.drop(['Model'], axis=1)

# Visualización dataset
dataTraining.head()
# Out:
#    Price  Year  Mileage    M_1  M_15002WD  M_15004WD  M_1500Laramie  \
# 0  34995  2017     9913  False      False      False          False
# 1  37895  2015    20578  False      False      False          False
# 2  18430  2012    83716  False      False      False          False
# 3  24681  2014    28729  False      False      False          False
# 4  26998  2013    64032  False      False      False          False
#
#    M_1500Tradesman  M_200LX  M_200Limited  ...  M_Yaris4dr  M_YarisBase  \
# 0            False    False         False  ...       False        False
# 1            False    False         False  ...       False        False
# 2            False    False         False  ...       False        False
# 3            False    False         False  ...       False        False
# 4            False    False         False  ...       False        False
#
#    M_YarisLE  M_Yukon  M_Yukon2WD  M_Yukon4WD  M_Yukon4dr  M_tC2dr  M_xB5dr  \
# 0      False    False       False       False       False    False    False
# 1      False    False       False       False       False    False    False
# 2      False    False       False       False       False    False    False
# 3      False    False       False       False       False    False    False
# 4      False    False       False       False       False    False    False
#
#    M_xD5dr
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
#
# [5 rows x 528 columns]

# %%
# Preprocesamiento de datos
dataTesting = dataTesting.drop(['Make', 'State'], axis=1)
dataTesting = dataTesting.join(pd.get_dummies(dataTesting['Model'], prefix='M'))
dataTesting = dataTesting.drop(['Model'], axis=1)

# Visualización dataset
dataTesting.head()
# Out:
#     Year  Mileage    M_1  M_15002WD  M_15004WD  M_1500Laramie  \
# ID
# 0   2014    31909  False      False      False          False
# 1   2017     5362  False      False      False          False
# 2   2014    50300  False      False      False          False
# 3   2004   132160  False      False      False          False
# 4   2015    25226  False      False      False          False
#
#     M_1500Tradesman  M_200LX  M_200Limited  M_200S  ...  M_Yaris4dr  \
# ID                                                  ...
# 0             False    False         False   False  ...       False
# 1             False    False         False   False  ...       False
# 2             False    False         False   False  ...       False
# 3             False    False         False   False  ...       False
# 4             False    False         False   False  ...       False
#
#     M_YarisBase  M_YarisLE  M_Yukon  M_Yukon2WD  M_Yukon4WD  M_Yukon4dr  \
# ID
# 0         False      False    False       False       False       False
# 1         False      False    False       False       False       False
# 2         False      False    False       False       False       False
# 3         False      False    False       False       False       False
# 4         False      False    False       False       False       False
#
#     M_tC2dr  M_xB5dr  M_xD5dr
# ID
# 0     False    False    False
# 1     False    False    False
# 2     False    False    False
# 3     False    False    False
# 4     False    False    False
#
# [5 rows x 527 columns]

# %%
# Separación de datos en set de entrenamiento y test

X_train = dataTraining.drop(['Price'], axis=1)
y_train = dataTraining['Price']
X_test = dataTesting

# %%
# Visualización de la información
# Gráfica del salario, años y hits
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
dataTraining.plot(kind='scatter', x='Year', y='Mileage', c='Price', colormap='jet', xlim=(1995, 2020), ylim=(0, 300000))
# Out:
# <Axes: xlabel='Year', ylabel='Mileage'>

# %% [markdown]
# ## Calibración del modelo (15 puntos)
#
# Se calibran los parámetros que se consideren pertinentes del modelo de clasificación seleccionado. (5 puntos)
#
# Se justifica el método seleccionado de calibración. (5 puntos)
#
# Se analizan los valores calibrados de cada parámetro y se explica cómo afectan el modelo. (5 puntos)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV

modelo = xgb.XGBRegressor(objective='reg:squarederror')

parametros = {
    'learning_rate': [0.4],
    'n_estimators': [550],
    'max_depth': [7],
    'colsample_bytree': [0.9],
    'subsample': [1],
    'reg_lambda': [2]
    
}

grid_search_xgb = GridSearchCV(estimator=modelo, param_grid=parametros, cv=3, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)

grid_search_xgb.fit(X_train, y_train)

print("Mejores parametros:", grid_search_xgb.best_params_)

mejor_modelo = grid_search_xgb.best_estimator_

y = mejor_modelo.predict(X_test)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Mejores parametros: {'colsample_bytree': 0.9, 'learning_rate': 0.4, 'max_depth': 7, 'n_estimators': 550, 'reg_lambda': 2, 'subsample': 1}

# %%
# Exportar modelo a archivo binario .pkl
import joblib
joblib.dump(grid_search_xgb, 'precio_vehiculo.pkl', compress=3)
# Out:
# ['precio_vehiculo.pkl']

# %%
# Importación librerías
from flask import Flask
from flask_restx import Api, Resource, fields

# %%
# Definición aplicación Flask
app = Flask(__name__)

# Definición API Flask
api = Api(
    app, 
    version='1.0', 
    title='API Prediccion Precio Vehiculos',
    description='API Prediccion Precio Vehiculos')

ns = api.namespace('predict', 
     description='Precio Vehiculos')

# Definición argumentos o parámetros de la API
parser = api.parser()
parser.add_argument(
    'Year', type=int, required=True, help='Year of the car', location='args')
parser.add_argument(
    'Mileage', type=int, required=True, help='Mileage of the car', location='args')

columnas_modelo = True

if columnas_modelo:
    for col in X_train.columns:
        if col.startswith('M_'):
            parser.add_argument(col, type=float, required=False, help=f'{col} value', location='args')

resource_fields = api.model('Resource', {
    'Price': fields.Float,
})

# %%
# Definición de la clase para disponibilización
@ns.route('/')
class PricePrediction(Resource):

    @api.doc(parser=parser)
    @api.marshal_with(resource_fields)
    def get(self):
        args = parser.parse_args()
        year = args['Year']
        mileage = args['Mileage']
        modelo_diligenciado = None

        for col in X_train.columns:
            if col.startswith('M_') and args.get(col) is not None:
                modelo_diligenciado = args[col]
                break

        total_columnas = [[year, mileage, modelo_diligenciado]]
        pred_precio = grid_search_xgb.predict(total_columnas)

        return {
         "Precio": float(pred_precio[0])}, 200

# %%
# Ejecución de la aplicación que disponibiliza el modelo de manera local en el puerto 5000
app.run(debug=True, use_reloader=False, host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.11.3:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2024 00:22:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2024 00:22:23] "GET /swaggerui/swagger-ui.css HTTP/1.1" 304 -
# 127.0.0.1 - - [28/Apr/2024 00:22:23] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [28/Apr/2024 00:22:23] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [28/Apr/2024 00:22:23] "GET /swaggerui/droid-sans.css HTTP/1.1" 304 -
# 127.0.0.1 - - [28/Apr/2024 00:22:23] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2024 00:23:18] "GET /predict/?Year=2008&Mileage=5000&M_15002WD=1 HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\app.py", line 1498, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\app.py", line 1476, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\api.py", line 671, in error_router
#     return original_handler(f)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\api.py", line 669, in error_router
#     return self.handle_error(e)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\api.py", line 671, in error_router
#     return original_handler(f)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\api.py", line 669, in error_router
#     return self.handle_error(e)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\api.py", line 402, in wrapper
#     resp = resource(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask\views.py", line 110, in view
#     return current_app.ensure_sync(self.dispatch_request)(**kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\resource.py", line 41, in dispatch_request
#     resp = meth(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\flask_restx\marshalling.py", line 244, in wrapper
#     resp = f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karen\AppData\Local\Temp\ipykernel_20580\339773559.py", line 19, in get
#     pred_precio = grid_search_xgb.predict(total_columnas)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py", line 546, in predict
#     return self.best_estimator_.predict(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1168, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\karen\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 2428, in inplace_predict
#     raise ValueError(
# ValueError: Feature shape mismatch, expected: 527, got 3

# %%
# Ejecución de la aplicación que disponibiliza el modelo de manera local en el puerto 5000
#app.run(debug=True, use_reloader=False, host='0.0.0.0', port=5000)

# %%
#y1 = pd.DataFrame(y)
#y1

# %%
#y1.insert(0, 'ID', range(0, len(y1)))
#y1

# %%
#y1.columns.values[1] = 'Price'
#y1

# %%
#y1.to_csv('test_submission11.csv', index=False)
